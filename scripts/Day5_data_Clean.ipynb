# %%
# ============================================
# DAY 5: DATA CLEANING TASKS
# ============================================

import pandas as pd

# 1. Load Dataset
df = pd.read_csv("data/student_scores_clean.csv")

print("--- 1. Initial Dataset ---")
print(df)
print("\nInitial Shape:", df.shape)

# 2. Check for Missing Values
print("\n--- 2. Checking Missing Values ---")
print(df.isnull().sum())

# Fill missing values with the mean of the column
df['Hours'] = df['Hours'].fillna(df['Hours'].mean())
print("\nMissing values after mean imputation:")
print(df.isnull().sum())

# 3. Check and Remove Duplicate Rows
print("\n--- 3. Checking Duplicates ---")
print("Duplicate count:", df.duplicated().sum())

df = df.drop_duplicates()
print("Shape after removing duplicates:", df.shape)

# 4. Save the Clean Dataset
clean_filename = "student_scores_clean.csv"
df.to_csv(clean_filename, index=False)
print(f"\n--- 4. Clean Dataset Saved as '{clean_filename}' ---")

# 5. Final Dataset Summary Statistics
print("\n--- 5. Clean Dataset Statistics ---")
print(df.describe())
# Out:
# --- 1. Initial Dataset ---
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    NaN      35
# 11    5.1      47
#
# Initial Shape: (12, 2)
#
# --- 2. Checking Missing Values ---
# Hours     1
# Scores    0
# dtype: int64
#
# Missing values after mean imputation:
# Hours     0
# Scores    0
# dtype: int64
#
# --- 3. Checking Duplicates ---
# Duplicate count: 1
# Shape after removing duplicates: (11, 2)
#
# --- 4. Clean Dataset Saved as 'student_scores_clean.csv' ---
#
# --- 5. Clean Dataset Statistics ---
#            Hours     Scores
# count  11.000000  11.000000
# mean    5.000826  46.272727
# std     2.651793  25.507218
# min     1.500000  20.000000
# 25%     2.950000  26.000000
# 50%     5.009091  35.000000
# 75%     6.900000  67.500000
# max     9.200000  88.000000
